# %%
import pandas as pd

def preprocess_metabolites(file_path):
    """
    Reads the metabolites data, sets the 'Compound' column as the index,
    and transposes the DataFrame so that Sample IDs become rows.
    """
    # Read the file as a CSV. Since the file is .txt with tabs, we use sep='\t'.
    df = pd.read_csv(file_path, sep='\t')
    
    # Set 'Compound' as the index. 
    # This ensures that when we transpose, the compound names become the column headers.
    df.set_index('Compound', inplace=True)
    
    # Transpose the DataFrame (swap rows and columns).
    # Now, the index will contain the Sample IDs.
    df_transposed = df.T
    
    # Optional: If you want to convert the index (Sample IDs) back into a regular column:
    # df_transposed.reset_index(inplace=True)
    # df_transposed.rename(columns={'index': 'Sample_ID'}, inplace=True)
    
    return df_transposed

# Example usage:
# Assuming the file is in the current directory
df = preprocess_metabolites('/home/pintokf/Projects/Microbium/Mouses/mouses_2_data/meatabolites.txt')

# Display the first 5 rows to verify the transposition
print(df.head())
# Out:
# Compound   303.2925@9.854003  LysoPC(18:0)  \
# 18-1_5-20       9.201675e+05  2.482322e+07
# 18-2_5-20       4.924285e+07  1.985832e+07
# 20-0_5-20       5.563117e+07  1.198559e+07
# 20-1_5-20       6.809295e+05  1.270308e+07
# 21-1_5-20       7.940316e+06  5.943284e+06
#
# Compound   1-Palmitoyllysophosphatidylcholine  102.0467@1.030999  \
# 18-1_5-20                         19210210.61       1.281915e+07
# 18-2_5-20                         21473648.52       1.972746e+07
# 20-0_5-20                         18643611.25       9.666800e+06
# 20-1_5-20                         16540001.16       4.491578e+06
# 21-1_5-20                         14601952.94       8.293789e+06
#
# Compound   331.3236@10.99799  378.2891@7.2789965  \
# 18-1_5-20       1.321896e+06        6.886311e+06
# 18-2_5-20       2.223548e+07        1.014112e+07
# 20-0_5-20       2.757008e+07        7.622998e+06
# 20-1_5-20       1.161169e+06        6.392904e+06
# 21-1_5-20       5.461554e+06        8.205137e+06
#
# Compound   2-Hydroxy-4-imino-2,5-cyclohexadienone  Mesobilirubinogen  \
# 18-1_5-20                            7.681481e+06       1.016817e+07
# 18-2_5-20                            2.245875e+07       2.580433e+07
# 20-0_5-20                            7.195433e+06       1.479517e+07
# 20-1_5-20                            6.330706e+06       1.699591e+07
# 21-1_5-20                            3.862643e+06       6.988479e+06
#
# Compound   816.575@8.012004  1-Linoleoylglycerophosphocholine  ...  Furcatin  \
# 18-1_5-20      3.051692e+05                      8.148500e+06  ...  125747.0
# 18-2_5-20      2.746390e+05                      7.749630e+06  ...  117345.0
# 20-0_5-20      1.469555e+07                      5.961570e+06  ...  134928.0
# 20-1_5-20      1.554220e+06                      8.925657e+06  ...  104309.0
# 21-1_5-20      5.358687e+05                      1.078388e+07  ...   60239.0
#
# Compound   all-trans-heptaprenyl diphosphate Esi-9.861  436.3181@12.823  \
# 18-1_5-20                                     207353.0         137460.0
# 18-2_5-20                                     164197.0         207279.0
# 20-0_5-20                                     371495.0         231983.0
# 20-1_5-20                                          1.0         103098.0
# 21-1_5-20                                      58925.0         111833.0
#
# Compound   1-Nitro-5,6-dihydroxy-dihydronaphthalene  252.0517@4.214  \
# 18-1_5-20                                       1.0        174813.0
# 18-2_5-20                                       1.0             1.0
# 20-0_5-20                                  306917.0        273052.0
# 20-1_5-20                                  222590.0        156489.0
# 21-1_5-20                                       1.0        168344.0
#
# Compound   Butyl oleate sulfate  Alisol A  363.95@0.40099964  \
# 18-1_5-20              108232.0   95662.0                1.0
# 18-2_5-20                   1.0  141664.0            73812.0
# 20-0_5-20                   1.0       1.0                1.0
# 20-1_5-20               65999.0  128930.0           141014.0
# 21-1_5-20                   1.0       1.0           174327.0
#
# Compound   511.8892@0.35700023  613.2694@10.275003
# 18-1_5-20             114666.0                 1.0
# 18-2_5-20              18795.0            379383.0
# 20-0_5-20                  1.0            311813.0
# 20-1_5-20              88982.0            363921.0
# 21-1_5-20             112376.0            238564.0
#
# [5 rows x 1889 columns]

# %%
import numpy as np

# 1. Relative Normalization
# Sum each row (calculate the total abundance per sample)
row_sums = df.sum(axis=1)

# Divide each value by its corresponding row sum
df_normalized = df.div(row_sums, axis=0)

# 2. Log Transformation with Epsilon
# Define a small epsilon to avoid log(0) errors
epsilon = 1e-10

# Add epsilon and apply natural logarithm (log base e)
df_log = np.log(df_normalized + epsilon)

# Display the first 5 rows of the transformed data
print("Transformed data (Log of Relative Abundance):")
print(df_log.head())

# Optional: Verify that rows summed to 1 before the log (should be very close to 1.0)
print(df_normalized.sum(axis=1).head())
# Out:
# Transformed data (Log of Relative Abundance):
# Compound   303.2925@9.854003  LysoPC(18:0)  \
# 18-1_5-20          -7.787398     -4.492419
# 18-2_5-20          -3.996977     -4.905119
# 20-0_5-20          -4.007231     -5.542270
# 20-1_5-20          -8.150380     -5.224239
# 21-1_5-20          -5.721256     -6.010948
#
# Compound   1-Palmitoyllysophosphatidylcholine  102.0467@1.030999  \
# 18-1_5-20                           -4.748757          -5.153259
# 18-2_5-20                           -4.826915          -4.911730
# 20-0_5-20                           -5.100471          -5.757277
# 20-1_5-20                           -4.960302          -6.263879
# 21-1_5-20                           -5.112054          -5.677703
#
# Compound   331.3236@10.99799  378.2891@7.2789965  \
# 18-1_5-20          -7.425132           -5.774663
# 18-2_5-20          -4.792053           -5.577143
# 20-0_5-20          -4.709243           -5.994805
# 20-1_5-20          -7.616656           -5.910895
# 21-1_5-20          -6.095476           -5.688449
#
# Compound   2-Hydroxy-4-imino-2,5-cyclohexadienone  Mesobilirubinogen  \
# 18-1_5-20                               -5.665386          -5.384936
# 18-2_5-20                               -4.782062          -4.643199
# 20-0_5-20                               -6.052528          -5.331673
# 20-1_5-20                               -5.920672          -4.933111
# 21-1_5-20                               -6.441858          -5.848947
#
# Compound   816.575@8.012004  1-Linoleoylglycerophosphocholine  ...   Furcatin  \
# 18-1_5-20         -8.891087                         -5.606365  ...  -9.777680
# 18-2_5-20         -9.186038                         -5.846097  ... -10.036376
# 20-0_5-20         -5.338430                         -6.240640  ... -10.028986
# 20-1_5-20         -7.325110                         -5.577154  ... -10.026479
# 21-1_5-20         -8.417075                         -5.415157  ... -10.602641
#
# Compound   all-trans-heptaprenyl diphosphate Esi-9.861  436.3181@12.823  \
# 18-1_5-20                                    -9.277530        -9.688619
# 18-2_5-20                                    -9.700428        -9.467430
# 20-0_5-20                                    -9.016193        -9.487064
# 20-1_5-20                                   -21.369777       -10.038157
# 21-1_5-20                                   -10.624695        -9.983956
#
# Compound   1-Nitro-5,6-dihydroxy-dihydronaphthalene  252.0517@4.214  \
# 18-1_5-20                                -21.319414       -9.448236
# 18-2_5-20                                -21.471776      -21.471776
# 20-0_5-20                                 -9.207151       -9.324066
# 20-1_5-20                                 -9.268506       -9.620852
# 21-1_5-20                                -21.391668       -9.574954
#
# Compound   Butyl oleate sulfate   Alisol A  363.95@0.40099964  \
# 18-1_5-20             -9.927675 -10.051131         -21.319414
# 18-2_5-20            -21.471776  -9.848037         -10.499972
# 20-0_5-20            -21.574562 -21.574562         -21.574562
# 20-1_5-20            -10.484196  -9.814567          -9.724978
# 21-1_5-20            -21.391668 -21.391668          -9.540031
#
# Compound   511.8892@0.35700023  613.2694@10.275003
# 18-1_5-20            -9.869929          -21.319414
# 18-2_5-20           -11.867892           -8.862950
# 20-0_5-20           -21.574562           -9.191325
# 20-1_5-20           -10.185402           -8.776901
# 21-1_5-20            -9.979112           -9.226326
#
# [5 rows x 1889 columns]
# 18-1_5-20    1.0
# 18-2_5-20    1.0
# 20-0_5-20    1.0
# 20-1_5-20    1.0
# 21-1_5-20    1.0
# dtype: float64

# %%
# Apply Z-score normalization to each metabolite (column)
# Formula: z = (x - mean) / std
# This ensures all metabolites are on the same scale (mean=0, std=1)

# Calculate Z-score using pandas vectorization
# Note: axis=0 is the default, which calculates statistics per column
df_zscore = (df_log - df_log.mean()) / df_log.std()

# Display the first 5 rows of the Z-scored data
print("Data after Z-score normalization:")
print(df_zscore.head())

# Optional verification: 
# The mean of columns should be practically 0 and std should be 1
print("\nVerification (Means should be ~0, Stds should be ~1):")
print(df_zscore.mean().head())
print(df_zscore.std().head())
# Out:
# Data after Z-score normalization:
# Compound   303.2925@9.854003  LysoPC(18:0)  \
# 18-1_5-20          -0.217534      2.405604
# 18-2_5-20           0.873443      1.628247
# 20-0_5-20           0.870492      0.428116
# 20-1_5-20          -0.322009      1.027155
# 21-1_5-20           0.377153     -0.454681
#
# Compound   1-Palmitoyllysophosphatidylcholine  102.0467@1.030999  \
# 18-1_5-20                            1.264986           0.747120
# 18-2_5-20                            1.083734           1.149494
# 20-0_5-20                            0.449349          -0.259143
# 20-1_5-20                            0.774406          -1.103117
# 21-1_5-20                            0.422486          -0.126576
#
# Compound   331.3236@10.99799  378.2891@7.2789965  \
# 18-1_5-20          -0.080480            0.487793
# 18-2_5-20           0.623764            1.145846
# 20-0_5-20           0.645913           -0.245624
# 20-1_5-20          -0.131705            0.033927
# 21-1_5-20           0.275150            0.775021
#
# Compound   2-Hydroxy-4-imino-2,5-cyclohexadienone  Mesobilirubinogen  \
# 18-1_5-20                                0.813888           0.420675
# 18-2_5-20                                2.434592           2.062176
# 20-0_5-20                                0.103571           0.538548
# 20-1_5-20                                0.345497           1.420587
# 21-1_5-20                               -0.610763          -0.606203
#
# Compound   816.575@8.012004  1-Linoleoylglycerophosphocholine  ...  Furcatin  \
# 18-1_5-20         -1.171721                          0.937285  ...  0.519786
# 18-2_5-20         -1.374275                          0.507047  ...  0.458851
# 20-0_5-20          1.268021                         -0.201027  ...  0.460592
# 20-1_5-20         -0.096306                          0.989710  ...  0.461182
# 21-1_5-20         -0.846200                          1.280440  ...  0.325469
#
# Compound   all-trans-heptaprenyl diphosphate Esi-9.861  436.3181@12.823  \
# 18-1_5-20                                     0.626900         0.386799
# 18-2_5-20                                     0.549468         0.450736
# 20-0_5-20                                     0.674750         0.445061
# 20-1_5-20                                    -1.587166         0.285763
# 21-1_5-20                                     0.380237         0.301430
#
# Compound   1-Nitro-5,6-dihydroxy-dihydronaphthalene  252.0517@4.214  \
# 18-1_5-20                                 -1.525381        0.610720
# 18-2_5-20                                 -1.552840       -1.661215
# 20-0_5-20                                  0.657543        0.634182
# 20-1_5-20                                  0.646486        0.578103
# 21-1_5-20                                 -1.538403        0.586775
#
# Compound   Butyl oleate sulfate  Alisol A  363.95@0.40099964  \
# 18-1_5-20              0.731947  0.504099          -1.695710
# 18-2_5-20             -1.413407  0.546363           0.546829
# 20-0_5-20             -1.432509 -1.893936          -1.748595
# 20-1_5-20              0.628523  0.553328           0.707462
# 21-1_5-20             -1.398520 -1.855876           0.745796
#
# Compound   511.8892@0.35700023  613.2694@10.275003
# 18-1_5-20             0.617917           -1.759703
# 18-2_5-20             0.111682            0.629357
# 20-0_5-20            -2.347754            0.566377
# 20-1_5-20             0.537984            0.645860
# 21-1_5-20             0.590253            0.559664
#
# [5 rows x 1889 columns]
#
# Verification (Means should be ~0, Stds should be ~1):
# Compound
# 303.2925@9.854003                     2.498002e-16
# LysoPC(18:0)                          2.009195e-15
# 1-Palmitoyllysophosphatidylcholine   -9.490865e-16
# 102.0467@1.030999                    -1.517305e-15
# 331.3236@10.99799                     2.255141e-16
# dtype: float64
# Compound
# 303.2925@9.854003                     1.0
# LysoPC(18:0)                          1.0
# 1-Palmitoyllysophosphatidylcholine    1.0
# 102.0467@1.030999                     1.0
# 331.3236@10.99799                     1.0
# dtype: float64

# %%
# 1. Rename the Index just to be clear (it's currently named 'Compound')
df_zscore.index.name = 'SampleID'

# 2. Check the head again - now you will see 'SampleID' on the top left
print(df_zscore.head())

df_zscore.to_csv('/home/pintokf/Projects/Microbium/Mouses/preprocess_metabolits/preprocessed_metabolites_normalized_z_score.csv', index=True)
# Out:
# Compound   303.2925@9.854003  LysoPC(18:0)  \
# SampleID
# 18-1_5-20          -0.217534      2.405604
# 18-2_5-20           0.873443      1.628247
# 20-0_5-20           0.870492      0.428116
# 20-1_5-20          -0.322009      1.027155
# 21-1_5-20           0.377153     -0.454681
#
# Compound   1-Palmitoyllysophosphatidylcholine  102.0467@1.030999  \
# SampleID
# 18-1_5-20                            1.264986           0.747120
# 18-2_5-20                            1.083734           1.149494
# 20-0_5-20                            0.449349          -0.259143
# 20-1_5-20                            0.774406          -1.103117
# 21-1_5-20                            0.422486          -0.126576
#
# Compound   331.3236@10.99799  378.2891@7.2789965  \
# SampleID
# 18-1_5-20          -0.080480            0.487793
# 18-2_5-20           0.623764            1.145846
# 20-0_5-20           0.645913           -0.245624
# 20-1_5-20          -0.131705            0.033927
# 21-1_5-20           0.275150            0.775021
#
# Compound   2-Hydroxy-4-imino-2,5-cyclohexadienone  Mesobilirubinogen  \
# SampleID
# 18-1_5-20                                0.813888           0.420675
# 18-2_5-20                                2.434592           2.062176
# 20-0_5-20                                0.103571           0.538548
# 20-1_5-20                                0.345497           1.420587
# 21-1_5-20                               -0.610763          -0.606203
#
# Compound   816.575@8.012004  1-Linoleoylglycerophosphocholine  ...  Furcatin  \
# SampleID                                                       ...
# 18-1_5-20         -1.171721                          0.937285  ...  0.519786
# 18-2_5-20         -1.374275                          0.507047  ...  0.458851
# 20-0_5-20          1.268021                         -0.201027  ...  0.460592
# 20-1_5-20         -0.096306                          0.989710  ...  0.461182
# 21-1_5-20         -0.846200                          1.280440  ...  0.325469
#
# Compound   all-trans-heptaprenyl diphosphate Esi-9.861  436.3181@12.823  \
# SampleID
# 18-1_5-20                                     0.626900         0.386799
# 18-2_5-20                                     0.549468         0.450736
# 20-0_5-20                                     0.674750         0.445061
# 20-1_5-20                                    -1.587166         0.285763
# 21-1_5-20                                     0.380237         0.301430
#
# Compound   1-Nitro-5,6-dihydroxy-dihydronaphthalene  252.0517@4.214  \
# SampleID
# 18-1_5-20                                 -1.525381        0.610720
# 18-2_5-20                                 -1.552840       -1.661215
# 20-0_5-20                                  0.657543        0.634182
# 20-1_5-20                                  0.646486        0.578103
# 21-1_5-20                                 -1.538403        0.586775
#
# Compound   Butyl oleate sulfate  Alisol A  363.95@0.40099964  \
# SampleID
# 18-1_5-20              0.731947  0.504099          -1.695710
# 18-2_5-20             -1.413407  0.546363           0.546829
# 20-0_5-20             -1.432509 -1.893936          -1.748595
# 20-1_5-20              0.628523  0.553328           0.707462
# 21-1_5-20             -1.398520 -1.855876           0.745796
#
# Compound   511.8892@0.35700023  613.2694@10.275003
# SampleID
# 18-1_5-20             0.617917           -1.759703
# 18-2_5-20             0.111682            0.629357
# 20-0_5-20            -2.347754            0.566377
# 20-1_5-20             0.537984            0.645860
# 21-1_5-20             0.590253            0.559664
#
# [5 rows x 1889 columns]

# %%
df_zscore.shape
# Out:
# (72, 1889)

# %%
"ID" in df_zscore.columns or "Sample" in df_zscore.columns
# Out:
# False
